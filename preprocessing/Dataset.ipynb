# %%
import pandas as pd

# %%
datasets = pd.read_json('./wikidata/datasets.json')

# %%
datasets['id'] = datasets.apply(lambda row: row['item'].split("/")[-1], axis=1)

# %%
datasets = datasets[~(datasets['itemLabel']==datasets['id'])]

# %%
datasets['label_len'] = datasets.apply(lambda row: len(row['itemLabel'].split(" ")), axis=1)

# %%
datasets = datasets[datasets['label_len']<6]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('discography'))]

# %%
alg_set = set(datasets['instance_ofLabel'])
d = {}
for entry in alg_set:
    d[entry] = len(datasets[datasets['instance_ofLabel'] == entry])

# %%
d_10 = {}
for key, value in d.items():
    if value < 10:
        d_10[key] = value

# %%
len(d_10)
# Out:
# 682

# %%
datasets
# Out:
#                                             item  \
# 88      http://www.wikidata.org/entity/Q56580316
# 89      http://www.wikidata.org/entity/Q56580316
# 92      http://www.wikidata.org/entity/Q56863002
# 95      http://www.wikidata.org/entity/Q57631658
# 104     http://www.wikidata.org/entity/Q30309204
# ...                                          ...
# 65670  http://www.wikidata.org/entity/Q104445109
# 65671  http://www.wikidata.org/entity/Q104445109
# 65672  http://www.wikidata.org/entity/Q105103209
# 65673   http://www.wikidata.org/entity/Q64152253
# 65674   http://www.wikidata.org/entity/Q64152299
#
#                                    itemLabel  \
# 88           Skansens buidlings environments
# 89           Skansens buidlings environments
# 92     Drug Indications Extracted from FAERS
# 95                          10,000 Immunomes
# 104                             AIFB DataSet
# ...                                      ...
# 65670           The literature on marsupials
# ...

# %%
for key in d_10.keys():
    try:
        datasets = datasets[~(datasets['instance_ofLabel'].str.contains(key))]
    except:
        pass

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('dictionary'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('Census'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('Wiki'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('wiki'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('census'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('game'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('ROM hack'))]
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('bibliograph'))]

# %%
datasets
# Out:
#                                             item  \
# 89      http://www.wikidata.org/entity/Q56580316
# 125     http://www.wikidata.org/entity/Q36846256
# 127     http://www.wikidata.org/entity/Q36948990
# 143     http://www.wikidata.org/entity/Q42722842
# 146     http://www.wikidata.org/entity/Q42722842
# ...                                          ...
# 65668   http://www.wikidata.org/entity/Q97163982
# 65669  http://www.wikidata.org/entity/Q104445109
# 65672  http://www.wikidata.org/entity/Q105103209
# 65673   http://www.wikidata.org/entity/Q64152253
# 65674   http://www.wikidata.org/entity/Q64152299
#
#                              itemLabel  \
# 89     Skansens buidlings environments
# 125         Large Movie Review Dataset
# 127        20th Century Press Archives
# 143                    Paradise Papers
# 146                    Paradise Papers
# ...                                ...
# 65668      Newer Super Mario Bros. Wii
# 65669     The literature on marsupials
# ...

# %%
print(len(set(datasets['instance_ofLabel'])))
set(datasets['instance_ofLabel'])
# Out:
# 135
# {'501(c)(3) organization',
#  'Add-on',
#  'C++ header',
#  'Census in Turkey',
#  'Census in the Philippines',
#  'Cyprus census',
#  'Google Chrome extension',
#  'ISO standard',
#  'Internet encyclopedia',
#  'Internet slang',
#  'MediaWiki skin',
#  'MediaWiki website',
#  'Norway census',
#  'Pantone color library',
#  'ROM hack',
#  'United States Census',
#  'Vikidia edition',
#  'Web archive',
#  "Who's Who",
#  'Wikimedia module',
#  'Wikimedia module using Wikidata',
#  'Wikimedia multi-site page',
#  'Wikipedia language edition',
#  'Wiktionary language edition',
#  'address book',
#  'adult website',
#  'application',
#  'archives',
#  'art catalog',
#  'art exhibition',
#  'astronomical catalog',
#  'astronomical survey',
#  'astrophotography',
#  'authority control',
#  'bibliographic database',
#  'bibliographic index',
#  'bibliography',
#  'biographical database',
#  'biological database',
#  'bitext',
#  'book',
#  'book series',
#  'business',
#  'cadastre',
# ...

# %%
d_sorted = dict(sorted(d.items(), key=lambda item: item[1]))
d_sorted
# Out:
# {'library': 10,
#  'chemical database': 11,
#  'pathfinder (library science)': 11,
#  'global species database': 11,
#  'knowledge base': 12,
#  'medical database': 13,
#  'television series database': 13,
#  'wiki with script conversion': 14,
#  'bibliographic index': 14,
#  'music database': 15,
#  'Pantone color library': 16,
#  'pornographic actor or erotic model database': 18,
#  'wiki': 18,
#  'citation index': 20,
#  'geographical database': 24,
#  'biographical database': 25,
#  'encyclopedia': 27,
#  'taxonomic database': 27,
#  'sports database': 35,
#  'virtual library': 52,
#  'library catalog': 66,
#  'data library': 89,
#  'online music database': 99,
#  'database': 123,
#  'biological database': 159,
#  'bibliographic database': 202,
#  'Internet encyclopedia': 285,
#  'digital library': 342,
#  'online database': 1264}

# %%
len(d_sorted)
# Out:
# 29

# %%
possible_entries = ["set", 'Linked Data Platform', 'OWL ontology', 'database', 'register', 'library', 'knowledge', 'index', 'encyclopedia', 'wiki']

# %%
datasets = datasets[datasets['instance_ofLabel'].str.contains('|'.join(possible_entries))]

# %%
datasets[datasets['instance_ofLabel']=='wiki']
# Out:
#                                             item  \
# 4344    http://www.wikidata.org/entity/Q96749131
# 4795      http://www.wikidata.org/entity/Q803722
# 4810     http://www.wikidata.org/entity/Q1203487
# 4828     http://www.wikidata.org/entity/Q1348020
# 4854     http://www.wikidata.org/entity/Q2739005
# 5160      http://www.wikidata.org/entity/Q187491
# 5360     http://www.wikidata.org/entity/Q7999862
# 5362     http://www.wikidata.org/entity/Q9049446
# 5412    http://www.wikidata.org/entity/Q19832999
# 6422   http://www.wikidata.org/entity/Q106462434
# 9720    http://www.wikidata.org/entity/Q29413994
# 9733    http://www.wikidata.org/entity/Q35856826
# 9749    http://www.wikidata.org/entity/Q54806734
# 10189   http://www.wikidata.org/entity/Q80969895
# 10457   http://www.wikidata.org/entity/Q93262423
# 10741  http://www.wikidata.org/entity/Q107051959
# 34990   http://www.wikidata.org/entity/Q25105046
# 37412   http://www.wikidata.org/entity/Q55589669
#
# ...

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('edition of commercial catalogue'))]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('pathfinder'))]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('art catalog'))]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('compositions'))]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('porn'))]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('church'))]

# %%
datasets = datasets[~(datasets['instance_ofLabel'].str.contains('pornographic'))]

# %%
datasets_bare = datasets[['item', 'itemLabel']]

# %%
datasets_bare = datasets_bare.drop_duplicates()

# %%
datasets_bare = datasets_bare.reset_index(drop=True)

# %%
datasets_bare
# Out:
#                                           item  \
# 0     http://www.wikidata.org/entity/Q56580316
# 1     http://www.wikidata.org/entity/Q56863002
# 2     http://www.wikidata.org/entity/Q57631658
# 3     http://www.wikidata.org/entity/Q30309204
# 4     http://www.wikidata.org/entity/Q30337044
# ...                                        ...
# 4178  http://www.wikidata.org/entity/Q21693864
# 4179  http://www.wikidata.org/entity/Q26160336
# 4180  http://www.wikidata.org/entity/Q21831105
# 4181  http://www.wikidata.org/entity/Q80900474
# 4182  http://www.wikidata.org/entity/Q87326346
#
#                                      itemLabel
# 0              Skansens buidlings environments
# 1        Drug Indications Extracted from FAERS
# 2                             10,000 Immunomes
# 3                                 AIFB DataSet
# 4                                         COCO
# ...                                        ...
# 4178                            Otzar HaHochma
# ...
