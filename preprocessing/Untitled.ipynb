# %%
import pandas as pd

# %%
df = pd.read_json('/home/daniel/Downloads/datasets.json')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57199 entries, 0 to 57198
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   item       57199 non-null  object
#  1   itemLabel  57199 non-null  object
# dtypes: object(2)
# memory usage: 893.9+ KB

# %%
df['id'] = df.apply(lambda row: row['item'].split("/")[-1], axis=1)

# %%
df_filtered = df[~(df['itemLabel']==df['id'])]

# %%
df_filtered = df_filtered[~(df['itemLabel'].str.contains('discography'))]
# Out:
# /home/daniel/anaconda3/envs/KD/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_filtered['label_len'] = df_filtered.apply(lambda row: len(row['itemLabel'].split(" ")), axis=1)

# %%
df_filtered = df_filtered[df_filtered['label_len']<6]

# %%
df_filtered.tail(50)
# Out:
#                                             item  \
# 54060   http://www.wikidata.org/entity/Q17101857
# 54061   http://www.wikidata.org/entity/Q19367562
# 54062   http://www.wikidata.org/entity/Q19832796
# 54063   http://www.wikidata.org/entity/Q19871212
# 54064   http://www.wikidata.org/entity/Q19893718
# 54066   http://www.wikidata.org/entity/Q21494709
# 54067   http://www.wikidata.org/entity/Q21711071
# 54068   http://www.wikidata.org/entity/Q21711261
# 54069   http://www.wikidata.org/entity/Q21934251
# 54070   http://www.wikidata.org/entity/Q26877321
# 54071   http://www.wikidata.org/entity/Q27791793
# 54072  http://www.wikidata.org/entity/Q104904554
# 54075    http://www.wikidata.org/entity/Q3831775
# 54077   http://www.wikidata.org/entity/Q15707087
# 54078   http://www.wikidata.org/entity/Q22908122
# 54080   http://www.wikidata.org/entity/Q19597236
# 54081   http://www.wikidata.org/entity/Q61782534
# 54082    http://www.wikidata.org/entity/Q3490467
# ...

# %%
df_filtered = df_filtered[~(df['itemLabel'].str.contains('catalog'))]
df_filtered = df_filtered[~(df['itemLabel'].str.contains('albums'))]
# Out:
# /home/daniel/anaconda3/envs/KD/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/daniel/anaconda3/envs/KD/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df_filtered = df_filtered[~(df['itemLabel'].str.contains('bibliography'))]
df_filtered = df_filtered[~(df['itemLabel'].str.contains('Bibliography'))]
# Out:
# /home/daniel/anaconda3/envs/KD/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# /home/daniel/anaconda3/envs/KD/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df_filtered[200:250]
# Out:
#                                          item  \
# 488  http://www.wikidata.org/entity/Q66601587
# 489  http://www.wikidata.org/entity/Q66601589
# 492  http://www.wikidata.org/entity/Q66601594
# 493  http://www.wikidata.org/entity/Q66601597
# 494  http://www.wikidata.org/entity/Q66601601
# 496  http://www.wikidata.org/entity/Q66601606
# 497  http://www.wikidata.org/entity/Q66601609
# 498  http://www.wikidata.org/entity/Q66601615
# 518  http://www.wikidata.org/entity/Q66601669
# 520  http://www.wikidata.org/entity/Q66601671
# 521  http://www.wikidata.org/entity/Q66601673
# 522  http://www.wikidata.org/entity/Q66619043
# 523  http://www.wikidata.org/entity/Q66619044
# 524  http://www.wikidata.org/entity/Q66619045
# 525  http://www.wikidata.org/entity/Q66619046
# 526  http://www.wikidata.org/entity/Q66619047
# 532  http://www.wikidata.org/entity/Q66619054
# 533  http://www.wikidata.org/entity/Q66619055
# 552  http://www.wikidata.org/entity/Q66619076
# ...

# %%
algorithms = pd.read_json('/home/daniel/Downloads/methods/algorithms.json')

# %%
algorithms
# Out:
#                                            item  \
# 0          http://www.wikidata.org/entity/Q2799
# 1          http://www.wikidata.org/entity/Q4909
# 2          http://www.wikidata.org/entity/Q8548
# 3         http://www.wikidata.org/entity/Q72948
# 4         http://www.wikidata.org/entity/Q83886
# ...                                         ...
# 22473   http://www.wikidata.org/entity/Q1008943
# 22474   http://www.wikidata.org/entity/Q7272102
# 22475  http://www.wikidata.org/entity/Q10406839
# 22476  http://www.wikidata.org/entity/Q75116345
# 22477  http://www.wikidata.org/entity/Q84529696
#
#                                                itemLabel
# 0                                         delta encoding
# 1                             forward–backward algorithm
# 2                                   Dijkstra's algorithm
# 3                                           path tracing
# 4                                      Viterbi algorithm
# ...

# %%
#Filter out entities without names
algorithms['id'] = algorithms.apply(lambda row: row['item'].split("/")[-1], axis=1)
algorithms = algorithms[~(algorithms['itemLabel']==algorithms['id'])]

# %%
algorithms.tail(60)
# Out:
#                                             item  \
# 22405   http://www.wikidata.org/entity/Q96459963
# 22406   http://www.wikidata.org/entity/Q96573623
# 22407   http://www.wikidata.org/entity/Q96573823
# 22408   http://www.wikidata.org/entity/Q96573856
# 22409   http://www.wikidata.org/entity/Q96573862
# 22410   http://www.wikidata.org/entity/Q96573868
# 22411   http://www.wikidata.org/entity/Q96573894
# 22412   http://www.wikidata.org/entity/Q96573898
# 22413   http://www.wikidata.org/entity/Q96574024
# 22414   http://www.wikidata.org/entity/Q96649804
# 22415   http://www.wikidata.org/entity/Q97581572
# 22416   http://www.wikidata.org/entity/Q97581635
# 22417   http://www.wikidata.org/entity/Q97581771
# 22418   http://www.wikidata.org/entity/Q97581792
# 22419  http://www.wikidata.org/entity/Q106359702
# 22420  http://www.wikidata.org/entity/Q106481834
# 22421  http://www.wikidata.org/entity/Q106481928
# 22422  http://www.wikidata.org/entity/Q106481942
# ...

# %%
algorithms['label_len'] = algorithms.apply(lambda row: len(row['itemLabel'].split(" ")), axis=1)
algorithms = algorithms[algorithms['label_len']<5]
# Out:
# /home/daniel/anaconda3/envs/KD/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
